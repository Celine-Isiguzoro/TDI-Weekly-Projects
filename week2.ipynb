# %% [markdown]
# Week 2 Goal: Create a Python program that uses if/else statements, loops, and functions to process order and supplier data.
# Load the supply chain dataset for the first time and explore its structure.
#
# Task 1 : Using if/else statements, write code that:
# •   Takes an order value as input
# •	Checks if the order exceeds a threshold (10000)
# •	Prints an appropriate approval message

# %%
order_value = int(input("Enter the order value: "))

if order_value > 10000:
    print("Order value exceeded")
else:
    print("Order value approved")
# Out:
# Order value approved

# %% [markdown]
# Task 2: Create a list of order values and use a for loop to:
# •	Check each order
# •	Apply the same logic from Task 1 to each one
# •	Print results for all orders

# %%
order_list = [2000, 56000, 3400, 1000, 54990, 10000] # Sample list of order values

for order_value in order_list: # iterate through every item in the list
    if order_value > 10000:
        print(f"{order_value}: Order value exceeded")
    else:
        print(f"{order_value}: Order value approved")
# Out:
# 2000: Order value approved
# 56000: Order value exceeded
# 3400: Order value approved
# 1000: Order value approved
# 54990: Order value exceeded
# 10000: Order value approved

# %% [markdown]
# Task 3: Create a function called check_supplier_status that:
# •	Takes supplier_name and on_time_rate as parameters
# •	Returns a status based on the on_time_rate
# •	Test it with at least 3 different suppliers

# %%
def check_supplier_status(supplier_name, on_time_rate): # a check_supplier_status function was defined
        
        """
        Checks the status of the supplier based on the time rate
        Takes supplier name and on time rate as parameters
        Returns a status based on the time rate.

        """
        if on_time_rate >= 0.90:
            return f"{supplier_name}: Preferred supplier"
        elif on_time_rate >= 0.80:
            return f"{supplier_name}: Approved supplier"
        else:
            return f"{supplier_name}: Pending approval"
        
print(check_supplier_status.__doc__) # prints the documentation of the function
print(check_supplier_status("SupplierA", 0.50))
print(check_supplier_status("SupplierB", 0.97))
print(check_supplier_status("SupplierC", 0.81))
print(check_supplier_status("SupplierD", 0.45))
print(check_supplier_status("SupplierE", 0.67))
print(check_supplier_status("SupplierF", 1))
# Out:
# Checks the status of the supplier based on the time rate
# Takes supplier name and on time rate as parameters
# Returns a status based on the time rate.
#
#
# SupplierA: Pending approval
# SupplierB: Preferred supplier
# SupplierC: Approved supplier
# SupplierD: Pending approval
# SupplierE: Pending approval
# SupplierF: Preferred supplier

# %% [markdown]
# Task 4: You have been provided with a CSV file with supply chain data containing columns like: order_id, product_name, quantity, supplier_name, cost, delivery_date, status.
# Write code to:
# •	Open and read the CSV file
# •	Print the headers
# •	Print the total number of lines
# •	Print the first 5 data rows

# %%
import csv

with open ("supply_chain_dataset.csv", "r") as csv_file: # Opens the file and closes it when done to avoid data corruption
    csv_reader = csv.reader(csv_file) # Creates an object that reads the line by line

    # To read the headers
    headers = next(csv_reader) # Parsing the very first row into a variable for display and keeping it
    print("Headers:", headers)

#     # To print the total number of lines
    data = list(csv_reader)  # We must read all data first to be able to access its content
    total_number = len(data) # Total number of rows
    print(f"The total number of lines in this file: {total_number}")

    # To print the first 5 data rows
    for row in data[:5]:
        print(row)

        # OR

    # Using an incremental value
    counter = 1
    print("The first five rows: ")
    for row in data[:5]:
        print(f"Row {counter}: {row}")
        counter += 1

        # OR

    # Using the while loop
    row_num = 0
    while row_num < 5:
        print(f"Row {row_num + 1}, {data[row_num]}")
        row_num += 1
# Out:
# Headers: ['order_id', 'order_date', 'product_category', 'quantity', 'unit_price', 'total_cost', 'supplier_name', 'supplier_location', 'lead_time_days', 'warehouse_destination', 'delivery_date', 'actual_delivery_days', 'delivery_status', 'on_time', 'product_defects', 'return_status']
# The total number of lines in this file: 3000
# ['ORD-0001', '11/28/2022', 'Fasteners', '94', '64.49', '6062.06', 'SupplierE', 'Mexico', '32', 'Warehouse_3', '2022-12-30', '32', 'Delayed', 'Yes', '0.0', 'No Return']
# ['ORD-0002', '2022-02-20', 'Fasteners', '16', '76.63', '1226.08', 'Supplier E', 'Mexico', '17', 'Warehouse_2', '2022-03-09', '17', 'Delivered', 'Yes', '2.0', 'Partial Return']
# ['ORD-0003', '2022-11-03', 'Control Systems', '25', '2159.06', '53976.5', 'Supplier A', 'USA', '17', 'Warehouse_1', '2022-11-20', '17', 'Delivered', 'Yes', '0.0', '']
# ['ORD-0004', '2022-12-15', 'Valves', '33', '774.64', '25563.12', 'supplierc', 'China', '36', 'Warehouse_1', '2023-01-20', '36', 'Delivered', 'Yes', '0.0', 'No Return']
# ['ORD-0005', '2022-03-02', 'Motors', '13', '2091.41', '27188.33', 'supplierb', 'Germany', '15', 'Warehouse_6', '2022-03-17', '15', 'Delivered', 'Yes', '0.0', 'No Return']
# The first five rows:
# Row 1: ['ORD-0001', '11/28/2022', 'Fasteners', '94', '64.49', '6062.06', 'SupplierE', 'Mexico', '32', 'Warehouse_3', '2022-12-30', '32', 'Delayed', 'Yes', '0.0', 'No Return']
# Row 2: ['ORD-0002', '2022-02-20', 'Fasteners', '16', '76.63', '1226.08', 'Supplier E', 'Mexico', '17', 'Warehouse_2', '2022-03-09', '17', 'Delivered', 'Yes', '2.0', 'Partial Return']
# Row 3: ['ORD-0003', '2022-11-03', 'Control Systems', '25', '2159.06', '53976.5', 'Supplier A', 'USA', '17', 'Warehouse_1', '2022-11-20', '17', 'Delivered', 'Yes', '0.0', '']
# Row 4: ['ORD-0004', '2022-12-15', 'Valves', '33', '774.64', '25563.12', 'supplierc', 'China', '36', 'Warehouse_1', '2023-01-20', '36', 'Delivered', 'Yes', '0.0', 'No Return']
# Row 5: ['ORD-0005', '2022-03-02', 'Motors', '13', '2091.41', '27188.33', 'supplierb', 'Germany', '15', 'Warehouse_6', '2022-03-17', '15', 'Delivered', 'Yes', '0.0', 'No Return']
# Row 1, ['ORD-0001', '11/28/2022', 'Fasteners', '94', '64.49', '6062.06', 'SupplierE', 'Mexico', '32', 'Warehouse_3', '2022-12-30', '32', 'Delayed', 'Yes', '0.0', 'No Return']
# Row 2, ['ORD-0002', '2022-02-20', 'Fasteners', '16', '76.63', '1226.08', 'Supplier E', 'Mexico', '17', 'Warehouse_2', '2022-03-09', '17', 'Delivered', 'Yes', '2.0', 'Partial Return']
# Row 3, ['ORD-0003', '2022-11-03', 'Control Systems', '25', '2159.06', '53976.5', 'Supplier A', 'USA', '17', 'Warehouse_1', '2022-11-20', '17', 'Delivered', 'Yes', '0.0', '']
# Row 4, ['ORD-0004', '2022-12-15', 'Valves', '33', '774.64', '25563.12', 'supplierc', 'China', '36', 'Warehouse_1', '2023-01-20', '36', 'Delivered', 'Yes', '0.0', 'No Return']
# Row 5, ['ORD-0005', '2022-03-02', 'Motors', '13', '2091.41', '27188.33', 'supplierb', 'Germany', '15', 'Warehouse_6', '2022-03-17', '15', 'Delivered', 'Yes', '0.0', 'No Return']

# %% [markdown]
# Task 5: Using loops and logic, answer these questions by writing code:
# •	How many total rows of data are in the file?
# •	How many unique suppliers are there?
# •	What is the highest order cost?
# •	What is the lowest order cost?
# •	How many orders have a specific status (e.g., "Delivered")?
# Print each answer clearly labeled.

# %%
import csv
with open ("supply_chain_dataset.csv", "r") as file: # Open and close the file when done
    csv_reader = csv.reader(file)  # converts each rows to a dictionary
    data = list(csv_reader) # Converts it to a list of dictionaries
    total_num = len(data)
    print(f"Total number of rows in the file: {total_num}")

# To print the unique suppliers 
# We use the set data type to select distinct rows

unique_suppliers = set(row[6] for row in data) # Row is used to iterate through the dictionary "supplier_name"
total_unique_suppliers = len(unique_suppliers)
print(f"Total unique suppliers are {total_unique_suppliers}")

# To print the highest order cost
# highest_order_cost = max(float(row['total_cost']) for row in data) # Data is always in strings so it is necessary to change it to float
# String comparison uses alphabetical order so apparently 500 is higher than 10000 while number comparison uses actual value
# print(f"The highest order cost: {highest_order_cost} ")

# OR

with open ("supply_chain_dataset.csv", "r") as file:
    csv_reader = csv.reader(file)
    next(csv_reader) # No variable because I'm not keeping the headers
    data = list(csv_reader)

    highest_order_cost = max(float(row[5]) for row in data)
    print(f"The highest order cost: {highest_order_cost}")

# To print lowest order cost

with open("supply_chain_dataset.csv", "r") as file:
    csv_reader = csv.reader(file)
    next(csv_reader)
    data = list(csv_reader)

    lowest_order_cost = min(float(row[5]) for row in data) 
    print(f"The lowest order cost: {lowest_order_cost:.2f}")

# Number of orders with specific status
with open ("supply_chain_dataset.csv", "r") as file:
    csv_reader = csv.DictReader(file)
    data = list(csv_reader)

    delivered = 0
    cancelled = 0
    delayed = 0
    for row in data:
        if row['delivery_status'] == "Delivered":
            delivered += 1
        elif row['delivery_status'] == "Cancelled":
            cancelled += 1
        else:
            delayed += 1

    print(f"Number of delivered orders: {delivered} orders")
    print(f"Number of cancelled orders: {cancelled} orders")
    print(f"Number of delayed orders: {delayed} orders")
# Out:
# Total number of rows in the file: 3001
# Total unique suppliers are 16
# The highest order cost: 1720595.4
# The lowest order cost: -207.32
# Number of delivered orders: 2340 orders
# Number of cancelled orders: 64 orders
# Number of delayed orders: 596 orders

# %% [markdown]
# EXTRA CHALLENGE 1
# Write a function that takes an order value and supplier reliability score, then returns different approval levels based on both factors.

# %%
def approval_level (order_value, supplier_reliability_score):
    """
    Takes an order value and supplier reliability score, then returns different approval levels based on both factors
    """
    if order_value > 10000 or supplier_reliability_score > 70:
        return "Approved"
    elif order_value > 5000 and supplier_reliability_score > 50:
        return "Pending"
    elif order_value < 5000 or supplier_reliability_score == 0:
        return "Rejected"
    else:
        return "Cancelled"
    
print(approval_level(20000, 45))
print(approval_level(100000, 78))
# Out:
# Approved
# Approved

# %% [markdown]
# Challenge 2:
# Loop through the dataset and find all orders from a specific supplier. Count how many and calculate their total value

# %%
import csv

with open ("supply_chain_dataset.csv", "r") as file:
    csv_reader = csv.DictReader(file)
    data = list(csv_reader)

    count = 0
    total_value = 0
    for order in data:
        # print(order['supplier_name'])
        if order['supplier_name'] in ['SupplierE', 'Supplier E', 'suppliere']:
            count =+ 1
            total_value += float(order['total_cost'])

    print(f"Number of orders from SupplierE: {count}")
    print(f"The total value of orders from SupplierE is {total_value}")
# Out:
# Number of orders from SupplierA: 1
# The total value of orders from SupplierA is 4766913.091896022

# %% [markdown]
# Challenge 3:
# Loop through the dataset and identify any rows with missing data. Print which rows have problems and what's missing.

# %%
import csv # imports the python's csv library
with open ("supply_chain_dataset.csv", "r") as file: # opens and closes the csv file in read mode
    csv_reader = csv.DictReader(file) # converts each row to a dictionary
    data = list(csv_reader) # converts the dictionaries to a list of dictionaries

    for key, value in enumerate(data): # gives both the row number(incremental) and the data
        if "" in value.values() or None in value.values():
            missing_column = [] # stores all the columns with missing data 
            for column_name, column_value in value.items():
                if column_value == "" or column_value == None:
                    missing_column.append(column_name)
            print(f"The row {key} has a missing value{missing_column}")
# Out:
# The row 2 has a missing value['return_status']
# The row 9 has a missing value['product_defects']
# The row 29 has a missing value['return_status']
# The row 35 has a missing value['product_defects']
# The row 49 has a missing value['product_defects']
# The row 51 has a missing value['product_defects', 'return_status']
# The row 54 has a missing value['return_status']
# The row 57 has a missing value['return_status']
# The row 63 has a missing value['product_defects']
# The row 65 has a missing value['return_status']
# The row 90 has a missing value['return_status']
# The row 91 has a missing value['product_defects']
# The row 95 has a missing value['return_status']
# The row 108 has a missing value['product_defects']
# The row 138 has a missing value['return_status']
# The row 139 has a missing value['product_defects']
# The row 140 has a missing value['product_defects']
# The row 170 has a missing value['return_status']
# The row 180 has a missing value['product_defects']
# The row 200 has a missing value['return_status']
# The row 219 has a missing value['return_status']
# The row 231 has a missing value['return_status']
# The row 247 has a missing value['return_status']
# The row 252 has a missing value['return_status']
# The row 256 has a missing value['return_status']
# The row 263 has a missing value['product_defects']
# The row 272 has a missing value['return_status']
# The row 274 has a missing value['product_defects']
# The row 283 has a missing value['product_defects']
# The row 286 has a missing value['product_defects']
# The row 290 has a missing value['product_defects']
# The row 329 has a missing value['product_defects']
# The row 359 has a missing value['return_status']
# The row 361 has a missing value['return_status']
# The row 384 has a missing value['return_status']
# The row 416 has a missing value['return_status']
# The row 429 has a missing value['return_status']
# The row 430 has a missing value['return_status']
# The row 435 has a missing value['return_status']
# The row 437 has a missing value['product_defects']
# The row 451 has a missing value['product_defects']
# The row 454 has a missing value['product_defects']
# The row 456 has a missing value['product_defects']
# The row 470 has a missing value['product_defects']
# The row 487 has a missing value['product_defects']
# The row 498 has a missing value['product_defects']
# The row 500 has a missing value['product_defects']
# The row 503 has a missing value['product_defects']
# The row 528 has a missing value['return_status']
# The row 537 has a missing value['return_status']
# The row 544 has a missing value['product_defects']
# The row 569 has a missing value['product_defects']
# The row 570 has a missing value['product_defects']
# The row 573 has a missing value['return_status']
# The row 574 has a missing value['return_status']
# The row 579 has a missing value['return_status']
# The row 582 has a missing value['product_defects']
# The row 615 has a missing value['return_status']
# The row 624 has a missing value['return_status']
# The row 636 has a missing value['return_status']
# The row 672 has a missing value['return_status']
# The row 676 has a missing value['return_status']
# The row 677 has a missing value['return_status']
# The row 682 has a missing value['return_status']
# The row 683 has a missing value['product_defects']
# The row 691 has a missing value['product_defects']
# The row 697 has a missing value['product_defects']
# The row 702 has a missing value['product_defects', 'return_status']
# The row 720 has a missing value['product_defects']
# The row 741 has a missing value['product_defects']
# The row 759 has a missing value['product_defects']
# The row 770 has a missing value['return_status']
# The row 810 has a missing value['product_defects']
# The row 821 has a missing value['return_status']
# The row 825 has a missing value['product_defects']
# The row 828 has a missing value['return_status']
# The row 831 has a missing value['product_defects']
# The row 841 has a missing value['product_defects']
# The row 866 has a missing value['return_status']
# The row 882 has a missing value['return_status']
# The row 892 has a missing value['product_defects']
# The row 935 has a missing value['product_defects', 'return_status']
# The row 943 has a missing value['product_defects']
# The row 945 has a missing value['return_status']
# The row 946 has a missing value['product_defects']
# The row 948 has a missing value['return_status']
# The row 956 has a missing value['product_defects']
# The row 963 has a missing value['product_defects']
# The row 965 has a missing value['product_defects']
# The row 975 has a missing value['return_status']
# The row 981 has a missing value['product_defects']
# The row 1001 has a missing value['product_defects', 'return_status']
# The row 1010 has a missing value['product_defects']
# The row 1035 has a missing value['return_status']
# The row 1048 has a missing value['product_defects']
# The row 1066 has a missing value['return_status']
# The row 1080 has a missing value['product_defects']
# The row 1082 has a missing value['product_defects']
# The row 1097 has a missing value['product_defects']
# The row 1115 has a missing value['return_status']
# The row 1117 has a missing value['return_status']
# The row 1124 has a missing value['return_status']
# The row 1128 has a missing value['return_status']
# The row 1129 has a missing value['product_defects']
# The row 1157 has a missing value['product_defects']
# The row 1174 has a missing value['product_defects']
# The row 1187 has a missing value['return_status']
# The row 1191 has a missing value['product_defects']
# The row 1193 has a missing value['return_status']
# The row 1212 has a missing value['return_status']
# The row 1220 has a missing value['return_status']
# The row 1230 has a missing value['product_defects']
# The row 1269 has a missing value['product_defects']
# The row 1280 has a missing value['return_status']
# The row 1287 has a missing value['product_defects']
# The row 1294 has a missing value['product_defects']
# The row 1318 has a missing value['product_defects']
# The row 1332 has a missing value['product_defects']
# The row 1351 has a missing value['product_defects', 'return_status']
# The row 1357 has a missing value['product_defects']
# The row 1364 has a missing value['return_status']
# The row 1375 has a missing value['product_defects']
# The row 1386 has a missing value['product_defects']
# The row 1390 has a missing value['return_status']
# The row 1394 has a missing value['product_defects']
# The row 1406 has a missing value['return_status']
# The row 1408 has a missing value['product_defects']
# The row 1414 has a missing value['return_status']
# The row 1422 has a missing value['return_status']
# The row 1426 has a missing value['product_defects']
# The row 1433 has a missing value['product_defects']
# The row 1441 has a missing value['product_defects']
# The row 1450 has a missing value['product_defects']
# The row 1453 has a missing value['product_defects']
# The row 1457 has a missing value['return_status']
# The row 1488 has a missing value['product_defects']
# The row 1499 has a missing value['product_defects']
# The row 1501 has a missing value['product_defects']
# The row 1504 has a missing value['product_defects']
# The row 1513 has a missing value['product_defects']
# The row 1522 has a missing value['product_defects']
# The row 1545 has a missing value['return_status']
# The row 1547 has a missing value['return_status']
# The row 1549 has a missing value['product_defects']
# The row 1556 has a missing value['return_status']
# The row 1566 has a missing value['return_status']
# The row 1583 has a missing value['return_status']
# The row 1595 has a missing value['product_defects']
# The row 1601 has a missing value['product_defects']
# The row 1615 has a missing value['product_defects']
# The row 1619 has a missing value['return_status']
# The row 1621 has a missing value['product_defects']
# The row 1631 has a missing value['product_defects']
# The row 1646 has a missing value['return_status']
# The row 1650 has a missing value['product_defects']
# The row 1652 has a missing value['return_status']
# The row 1655 has a missing value['product_defects']
# The row 1659 has a missing value['product_defects']
# The row 1671 has a missing value['product_defects']
# The row 1679 has a missing value['product_defects']
# The row 1690 has a missing value['return_status']
# The row 1700 has a missing value['product_defects']
# The row 1702 has a missing value['product_defects']
# The row 1709 has a missing value['return_status']
# The row 1732 has a missing value['product_defects']
# The row 1733 has a missing value['return_status']
# The row 1734 has a missing value['return_status']
# The row 1750 has a missing value['product_defects']
# The row 1783 has a missing value['return_status']
# The row 1813 has a missing value['product_defects']
# The row 1817 has a missing value['product_defects']
# The row 1818 has a missing value['return_status']
# The row 1827 has a missing value['return_status']
# The row 1829 has a missing value['product_defects']
# The row 1846 has a missing value['product_defects']
# The row 1851 has a missing value['product_defects']
# The row 1859 has a missing value['return_status']
# The row 1882 has a missing value['return_status']
# The row 1892 has a missing value['return_status']
# The row 1893 has a missing value['return_status']
# The row 1896 has a missing value['product_defects', 'return_status']
# The row 1905 has a missing value['product_defects']
# The row 1922 has a missing value['product_defects']
# The row 1923 has a missing value['product_defects']
# The row 1931 has a missing value['return_status']
# The row 1948 has a missing value['return_status']
# The row 1956 has a missing value['return_status']
# The row 1957 has a missing value['return_status']
# The row 1958 has a missing value['product_defects']
# The row 1965 has a missing value['product_defects']
# The row 1970 has a missing value['product_defects']
# The row 1976 has a missing value['product_defects']
# The row 2021 has a missing value['return_status']
# The row 2023 has a missing value['return_status']
# The row 2031 has a missing value['return_status']
# The row 2032 has a missing value['product_defects']
# The row 2038 has a missing value['return_status']
# The row 2043 has a missing value['product_defects']
# The row 2062 has a missing value['return_status']
# The row 2086 has a missing value['return_status']
# The row 2088 has a missing value['return_status']
# The row 2089 has a missing value['product_defects']
# The row 2107 has a missing value['product_defects']
# The row 2113 has a missing value['product_defects']
# The row 2114 has a missing value['product_defects']
# The row 2125 has a missing value['product_defects']
# The row 2141 has a missing value['return_status']
# The row 2178 has a missing value['return_status']
# The row 2193 has a missing value['return_status']
# The row 2195 has a missing value['return_status']
# The row 2196 has a missing value['product_defects']
# The row 2216 has a missing value['product_defects']
# The row 2237 has a missing value['return_status']
# The row 2250 has a missing value['product_defects']
# The row 2255 has a missing value['product_defects']
# The row 2262 has a missing value['return_status']
# The row 2276 has a missing value['return_status']
# The row 2281 has a missing value['product_defects']
# The row 2301 has a missing value['return_status']
# The row 2317 has a missing value['return_status']
# The row 2320 has a missing value['return_status']
# The row 2323 has a missing value['return_status']
# The row 2337 has a missing value['return_status']
# The row 2348 has a missing value['return_status']
# The row 2350 has a missing value['product_defects']
# The row 2356 has a missing value['return_status']
# The row 2367 has a missing value['return_status']
# The row 2374 has a missing value['product_defects']
# The row 2377 has a missing value['return_status']
# The row 2379 has a missing value['return_status']
# The row 2382 has a missing value['product_defects']
# The row 2388 has a missing value['product_defects']
# The row 2389 has a missing value['return_status']
# The row 2393 has a missing value['return_status']
# The row 2408 has a missing value['return_status']
# The row 2416 has a missing value['product_defects']
# The row 2443 has a missing value['product_defects']
# The row 2452 has a missing value['return_status']
# The row 2460 has a missing value['return_status']
# The row 2462 has a missing value['return_status']
# The row 2464 has a missing value['product_defects']
# The row 2497 has a missing value['product_defects']
# The row 2502 has a missing value['return_status']
# The row 2512 has a missing value['product_defects']
# The row 2513 has a missing value['return_status']
# The row 2514 has a missing value['product_defects']
# The row 2518 has a missing value['return_status']
# The row 2520 has a missing value['return_status']
# The row 2558 has a missing value['product_defects']
# The row 2572 has a missing value['return_status']
# The row 2574 has a missing value['return_status']
# The row 2583 has a missing value['return_status']
# The row 2625 has a missing value['return_status']
# The row 2653 has a missing value['product_defects']
# The row 2685 has a missing value['product_defects']
# The row 2689 has a missing value['return_status']
# The row 2700 has a missing value['product_defects']
# The row 2708 has a missing value['product_defects']
# The row 2713 has a missing value['return_status']
# The row 2723 has a missing value['return_status']
# The row 2728 has a missing value['product_defects']
# The row 2731 has a missing value['product_defects']
# The row 2732 has a missing value['return_status']
# The row 2746 has a missing value['product_defects']
# The row 2747 has a missing value['product_defects']
# The row 2748 has a missing value['return_status']
# The row 2755 has a missing value['return_status']
# The row 2756 has a missing value['product_defects']
# The row 2757 has a missing value['return_status']
# The row 2793 has a missing value['product_defects']
# The row 2803 has a missing value['product_defects']
# The row 2810 has a missing value['return_status']
# The row 2830 has a missing value['return_status']
# The row 2832 has a missing value['return_status']
# The row 2835 has a missing value['return_status']
# The row 2843 has a missing value['return_status']
# The row 2844 has a missing value['return_status']
# The row 2850 has a missing value['return_status']
# The row 2860 has a missing value['product_defects']
# The row 2865 has a missing value['product_defects']
# The row 2887 has a missing value['return_status']
# The row 2897 has a missing value['product_defects']
# The row 2901 has a missing value['product_defects']
# The row 2908 has a missing value['return_status']
# The row 2912 has a missing value['product_defects']
# The row 2918 has a missing value['return_status']
# The row 2941 has a missing value['product_defects']
# The row 2942 has a missing value['product_defects']
# The row 2948 has a missing value['return_status']
# The row 2962 has a missing value['product_defects']
# The row 2976 has a missing value['product_defects']
# The row 2981 has a missing value['product_defects']
# The row 2983 has a missing value['product_defects', 'return_status']
